# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Salary_Data.csv")

# %%
X=df["YearsExperience"].values
Y=df["Salary"].values

# %%
X
# Out:
# array([ 1.1,  1.3,  1.5,  2. ,  2.2,  2.9,  3. ,  3.2,  3.2,  3.7,  3.9,
#         4. ,  4. ,  4.1,  4.5,  4.9,  5.1,  5.3,  5.9,  6. ,  6.8,  7.1,
#         7.9,  8.2,  8.7,  9. ,  9.5,  9.6, 10.3, 10.5])

# %%
Y
# Out:
# array([ 39343,  46205,  37731,  43525,  39891,  56642,  60150,  54445,
#         64445,  57189,  63218,  55794,  56957,  57081,  61111,  67938,
#         66029,  83088,  81363,  93940,  91738,  98273, 101302, 113812,
#        109431, 105582, 116969, 112635, 122391, 121872])

# %%
def mean(X):
    return sum(X)/len(X)

def variance(X):
    mean_value=mean(X)
    return sum((X-mean_value)**2)/len(X)

# %%
def norm(X):
    mean_value=mean(X)
    var_value=variance(X)
    return (X-mean_value)/np.sqrt(var_value)

# %%
X_norm=norm(X)

# %%
plt.plot(X_norm, Y)

# %%
plt.plot(X,Y)

# %%
from sklearn.linear_model import LinearRegression as LR

# %%
X_norm=X_norm.reshape(-1,1) # reshaping to make it a 2D array
# many machine learning algorithms expect the input to be a 2D array, where each row represents a sample and each column represents a feature. By reshaping X_norm to have one column, we ensure that it is in the correct format for the LinearRegression model. This allows us to fit the model properly and make predictions based on the normalized years of experience.
# if no reshape - n elements in 1d array - error

# %%
reg = LR().fit(X_norm, Y)

# %%
print(reg.score(X_norm, Y)) # regression score or r2 score - how well the model fits the data. It ranges from 0 to 1, where 1 indicates a perfect fit and 0 indicates that the model does not explain any of the variability in the target variable.
print(reg.coef_)
print(reg.intercept_)
# Out:
# 0.9569566641435086
# [26367.18244354]
# 76003.0

# %%
y_predict=reg.predict(X_norm)
print(y_predict)
# Out:
# [ 36187.15875227  38077.15121656  39967.14368085  44692.12484158
#   46582.11730587  53197.09093089  54142.08716303  56032.07962732
#   56032.07962732  60757.06078805  62647.05325234  63592.04948449
#   63592.04948449  64537.04571663  68317.03064522  72097.0155738
#   73987.00803809  75877.00050238  81546.97789525  82491.9741274
#   90051.94398456  92886.932681   100446.90253816 103281.8912346
#  108006.87239533 110841.86109176 115566.84225249 116511.83848464
#  123126.81210966 125016.80457395]

# %%
plt.plot(X_norm, Y)
plt.plot(X_norm, y_predict)
